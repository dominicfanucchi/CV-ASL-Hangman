# %% [markdown]
# # References
#
# 1. https://docs.opencv.org/4.x/index.html
# 2. https://opencv.org/university/free-opencv-course/?utm_source=opcvu&utm_medium=menu&utm_campaign=obc
# 3. https://www.geeksforgeeks.org/opencv-python-tutorial/#
# 4. https://www.youtube.com/watch?v=oXlwWbU8l2o
# 5. https://www.youtube.com/watch?v=eDIj5LuIL4A
